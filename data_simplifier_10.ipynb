# %%
import pandas as pd
df = pd.read_csv('Receipt_Data.csv', sep=";", encoding='ISO-8859-1')
df.head()
# Out:
#          Date  StoreNumber  CashRegisterNumber  ReceiptNumber  \
# 0  2022-01-03         1001                   1            296
# 1  2022-01-03         1001                   1            296
# 2  2022-01-03         1001                   1            296
# 3  2022-01-03         1001                   1            296
# 4  2022-01-03         1001                   1            296
#
#    ReceiptRowNumber      Time  ArticleNumber                ArticleName  \
# 0                 1  09:21:14         415945    AS Sandwich Weizen 750g
# 1                 2  09:21:14         428760          BR Alpensalz 500g
# 2                 3  09:21:14         413795  GL Gouda jung SHB oGt400g
# 3                 4  09:21:14         407194   Mondo Italiano Penne500g
# 4                 5  09:21:14         419727    GL H-Milch 3,5% 1L VLOG
#
#   Quantity
# 0   1,0000
# 1   1,0000
# 2   1,0000
# 3   1,0000
# 4   1,0000

# %%
# check missing value
df.isnull().sum()
# Out:
# Date                  0
# StoreNumber           0
# CashRegisterNumber    0
# ReceiptNumber         0
# ReceiptRowNumber      0
# Time                  0
# ArticleNumber         0
# ArticleName           0
# Quantity              0
# dtype: int64

# %%
# check data type
df.dtypes
# Out:
# Date                  object
# StoreNumber            int64
# CashRegisterNumber     int64
# ReceiptNumber          int64
# ReceiptRowNumber       int64
# Time                  object
# ArticleNumber          int64
# ArticleName           object
# Quantity              object
# dtype: object

# %%
# aggragate store 1436 and 2808 as they are the same
df.loc[df.StoreNumber==2808, 'StoreNumber'] = 1436

# %%
df.StoreNumber.unique()
# Out:
# array([1001, 1007, 1028, 1033, 1053, 1098, 1223, 1303, 1311, 1417, 1436,
#        1487, 1504, 2801])

# %%
# integrate "Date" and "Time"
df['Timestamp'] = df['Date'] + " " + df['Time']
df.head()
# Out:
#          Date  StoreNumber  CashRegisterNumber  ReceiptNumber  \
# 0  2022-01-03         1001                   1            296
# 1  2022-01-03         1001                   1            296
# 2  2022-01-03         1001                   1            296
# 3  2022-01-03         1001                   1            296
# 4  2022-01-03         1001                   1            296
#
#    ReceiptRowNumber      Time  ArticleNumber                ArticleName  \
# 0                 1  09:21:14         415945    AS Sandwich Weizen 750g
# 1                 2  09:21:14         428760          BR Alpensalz 500g
# 2                 3  09:21:14         413795  GL Gouda jung SHB oGt400g
# 3                 4  09:21:14         407194   Mondo Italiano Penne500g
# 4                 5  09:21:14         419727    GL H-Milch 3,5% 1L VLOG
#
#   Quantity            Timestamp
# 0   1,0000  2022-01-03 09:21:14
# 1   1,0000  2022-01-03 09:21:14
# 2   1,0000  2022-01-03 09:21:14
# 3   1,0000  2022-01-03 09:21:14
# 4   1,0000  2022-01-03 09:21:14

# %%
# change data type for column "Quantity", "Date"
# simplify quantity
df['Quantity'] = df['Quantity'].map(lambda x: float(str(x).split(",")[0] + "." + str(x).split(",")[1]))
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df.dtypes
# Out:
# Date                          object
# StoreNumber                    int64
# CashRegisterNumber             int64
# ReceiptNumber                  int64
# ReceiptRowNumber               int64
# Time                          object
# ArticleNumber                  int64
# ArticleName                   object
# Quantity                     float64
# Timestamp             datetime64[ns]
# dtype: object

# %%
# Make the 'Month', 'Day', 'Hour' column 
df['Month'] = df['Timestamp'].dt.month
df['Day'] = df['Timestamp'].dt.dayofweek
df['Hour'] = df['Timestamp'].dt.hour
df.head()
# Out:
#          Date  StoreNumber  CashRegisterNumber  ReceiptNumber  \
# 0  2022-01-03         1001                   1            296
# 1  2022-01-03         1001                   1            296
# 2  2022-01-03         1001                   1            296
# 3  2022-01-03         1001                   1            296
# 4  2022-01-03         1001                   1            296
#
#    ReceiptRowNumber      Time  ArticleNumber                ArticleName  \
# 0                 1  09:21:14         415945    AS Sandwich Weizen 750g
# 1                 2  09:21:14         428760          BR Alpensalz 500g
# 2                 3  09:21:14         413795  GL Gouda jung SHB oGt400g
# 3                 4  09:21:14         407194   Mondo Italiano Penne500g
# 4                 5  09:21:14         419727    GL H-Milch 3,5% 1L VLOG
#
#    Quantity           Timestamp  Month  Day  Hour
# 0       1.0 2022-01-03 09:21:14      1    0     9
# 1       1.0 2022-01-03 09:21:14      1    0     9
# 2       1.0 2022-01-03 09:21:14      1    0     9
# 3       1.0 2022-01-03 09:21:14      1    0     9
# 4       1.0 2022-01-03 09:21:14      1    0     9

# %%
# unique type of "ArticleName"
print(df['ArticleName'].unique())
print(len(df['ArticleName'].unique()))
# Out:
# ['AS Sandwich Weizen 750g' 'BR Alpensalz 500g' 'GL Gouda jung SHB oGt400g'
#  ... 'Cornetto S.Cookie 560ml' 'Paw Patrol Hoersp. 3ST'
#  'Epilierer Twist ST']
# 18228

# %%
display(df[df['Quantity']<0].head())
# Out:
#            Date  StoreNumber  CashRegisterNumber  ReceiptNumber  \
# 32   2022-01-03         1001                   1            302
# 41   2022-01-03         1001                   1            302
# 56   2022-01-03         1001                   1            304
# 77   2022-01-03         1001                   1            305
# 284  2022-01-03         1001                   2             25
#
#      ReceiptRowNumber      Time  ArticleNumber                ArticleName  \
# 32                  7  09:26:38         436646  Dil.gef.Weinblaetter 400g
# 41                 16  09:26:38          40010                  Ananas ST
# 56                  9  09:28:23         406990  PettiF.Meisenkn. 6ST 540g
# 77                  5  09:29:46            981                 Retoure EW
# 284                 5  16:42:41            980                 Retoure MW
#
#      Quantity           Timestamp  Month  Day  Hour
# 32       -1.0 2022-01-03 09:26:38      1    0     9
# 41       -1.0 2022-01-03 09:26:38      1    0     9
# 56       -1.0 2022-01-03 09:28:23      1    0     9
# 77       -1.0 2022-01-03 09:29:46      1    0     9
# 284      -1.0 2022-01-03 16:42:41      1    0    16

# %%
# Divide the data into two parts based on whether the quantity is positive or not
pos_quantity = df[df['Quantity']>0]
neg_quantity = df[df['Quantity']<0]
print(f"positive data are {pos_quantity.shape[0]}, negative data are {neg_quantity.shape[0]}")
# Out:
# positive data are 31720162, negative data are 1071990

# %%
# top by count Quantity in positive data
top_sales = pos_quantity.groupby('ArticleName')['Quantity'].sum().sort_values(ascending=False)[0:10]
print(top_sales)
# Out:
# ArticleName
# Pfandartikel (Tandem) - EW    2504867.000
# Pfandartikel (Tandem) - MW    1129948.000
# Gurken ST                      289314.000
# BO-Schnittbroetchen 1ST        282768.000
# BO-Laugenbreze 1ST             260322.000
# BO-Schnittbr.1ST               204974.000
# BO-Kaiserbroetchen 65g         192590.000
# Bananen Lose                   178036.223
# GL H-Milch1,5%1L VLOG          176058.000
# GL H-Milch 3,5% 1L VLOG        164628.000
# Name: Quantity, dtype: float64

# %%
# ignore the rest data and make a new .csv file
list_top = []
for iter in top_sales.index:
    list_top.append(iter)

top_df = pos_quantity[pos_quantity['ArticleName'].isin(list_top)]
def set_group(x):
    if x['ArticleName'] in ['Pfandartikel (Tandem) - EW', 'Pfandartikel (Tandem) - MW']:
        return "Pfandartikel"
    if x['ArticleName'] in ['BO-Schnittbr.1ST', 'BO-Schnittbroetchen 1ST', 'BO-Kaiserbroetchen 1ST', 'BO-Kaiserbroetchen 65g']:
        return "Broetchen"
    if x['ArticleName'] in ['GL H-Milch1,5%1L VLOG', 'GL H-Milch 3,5% 1L VLOG']:
        return "Milch"
    else:
        return x['ArticleName']
top_df['Group'] = top_df.apply(set_group, axis=1)
display(top_df.head())

top_df.to_csv('Article_top10_Data.csv')
# Out:
# /var/folders/2d/vw4mfsfj3_7fckcg_nmtp2tc0000gn/T/ipykernel_38884/1689509515.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_df['Group'] = top_df.apply(set_group, axis=1)
#           Date  StoreNumber  CashRegisterNumber  ReceiptNumber  \
# 4   2022-01-03         1001                   1            296
# 6   2022-01-03         1001                   1            296
# 19  2022-01-03         1001                   1            300
# 20  2022-01-03         1001                   1            300
# 75  2022-01-03         1001                   1            305
#
#     ReceiptRowNumber      Time  ArticleNumber                 ArticleName  \
# 4                  5  09:21:14         419727     GL H-Milch 3,5% 1L VLOG
# 6                  7  09:21:14   999999998025  Pfandartikel (Tandem) - EW
# 19                 1  09:25:34         421791          BO-Laugenbreze 1ST
# 20                 2  09:25:34         421791          BO-Laugenbreze 1ST
# 75                 3  09:29:46   999999998025  Pfandartikel (Tandem) - EW
#
#     Quantity           Timestamp  Month  Day  Hour               Group
# 4        1.0 2022-01-03 09:21:14      1    0     9               Milch
# 6        1.0 2022-01-03 09:21:14      1    0     9        Pfandartikel
# 19       1.0 2022-01-03 09:25:34      1    0     9  BO-Laugenbreze 1ST
# 20       1.0 2022-01-03 09:25:34      1    0     9  BO-Laugenbreze 1ST
# 75       1.0 2022-01-03 09:29:46      1    0     9        Pfandartikel
