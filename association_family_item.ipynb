# %%
import pandas as pd
df = pd.read_csv('Sales_data.csv')
df.head()
# Out:
#    Unnamed: 0        Date  StoreNumber  CashRegisterNumber  ReceiptNumber  \
# 0           0  2022-01-03         1001                   1            296
# 1           1  2022-01-03         1001                   1            296
# 2           2  2022-01-03         1001                   1            296
# 3           3  2022-01-03         1001                   1            296
# 4           4  2022-01-03         1001                   1            296
#
#    ReceiptRowNumber      Time  ArticleNumber                ArticleName  \
# 0                 1  09:21:14         415945    AS Sandwich Weizen 750g
# 1                 2  09:21:14         428760          BR Alpensalz 500g
# 2                 3  09:21:14         413795  GL Gouda jung SHB oGt400g
# 3                 4  09:21:14         407194   Mondo Italiano Penne500g
# 4                 5  09:21:14         419727    GL H-Milch 3,5% 1L VLOG
#
#    Quantity            Timestamp  Month  Day  Hour
# 0       1.0  2022-01-03 09:21:14      1    0     9
# 1       1.0  2022-01-03 09:21:14      1    0     9
# 2       1.0  2022-01-03 09:21:14      1    0     9
# 3       1.0  2022-01-03 09:21:14      1    0     9
# 4       1.0  2022-01-03 09:21:14      1    0     9

# %%
df = df.drop_duplicates(subset=['Date','StoreNumber', 'CashRegisterNumber', 'ReceiptNumber', 'ArticleName'], keep='first')
display(df.head())
display(df.shape)
# Out:
#    Unnamed: 0        Date  StoreNumber  CashRegisterNumber  ReceiptNumber  \
# 0           0  2022-01-03         1001                   1            296
# 1           1  2022-01-03         1001                   1            296
# 2           2  2022-01-03         1001                   1            296
# 3           3  2022-01-03         1001                   1            296
# 4           4  2022-01-03         1001                   1            296
#
#    ReceiptRowNumber      Time  ArticleNumber                ArticleName  \
# 0                 1  09:21:14         415945    AS Sandwich Weizen 750g
# 1                 2  09:21:14         428760          BR Alpensalz 500g
# 2                 3  09:21:14         413795  GL Gouda jung SHB oGt400g
# 3                 4  09:21:14         407194   Mondo Italiano Penne500g
# 4                 5  09:21:14         419727    GL H-Milch 3,5% 1L VLOG
#
#    Quantity            Timestamp  Month  Day  Hour
# 0       1.0  2022-01-03 09:21:14      1    0     9
# 1       1.0  2022-01-03 09:21:14      1    0     9
# 2       1.0  2022-01-03 09:21:14      1    0     9
# 3       1.0  2022-01-03 09:21:14      1    0     9
# 4       1.0  2022-01-03 09:21:14      1    0     9
# (24570611, 14)

# %%
df.loc[:,"ArticleName"][df.ArticleName.str.contains("Windel")] = "Windel"

# %%
list_ = []
for ind, row in df[df.ArticleName=='Windel'].iterrows():
    list_.append([row.Date, row.StoreNumber, row.CashRegisterNumber, row.ReceiptNumber])

# %%
list_[0:5]
# Out:
# [['2022-01-04', 1303, 2, 933],
#  ['2022-01-07', 1053, 2, 772],
#  ['2022-01-10', 1417, 1, 145],
#  ['2022-01-14', 1303, 1, 798],
#  ['2022-01-15', 1033, 3, 421]]

# %%
trans = pd.DataFrame()
for list in list_:
    Date = list[0]
    StoreNumber = list[1]
    CashRegisterNumber = list[2]
    ReceiptNumber = list[3]
    result = df.query(f"Date=='{Date}' & StoreNumber=={StoreNumber} & CashRegisterNumber=={CashRegisterNumber} & ReceiptNumber=={ReceiptNumber}")
    trans = pd.concat([trans, result], ignore_index=True)
display(trans.head())
# Out:
#    Unnamed: 0        Date  StoreNumber  CashRegisterNumber  ReceiptNumber  \
# 0      150088  2022-01-04         1303                   2            933
# 1      150089  2022-01-04         1303                   2            933
# 2      150090  2022-01-04         1303                   2            933
# 3      344645  2022-01-07         1053                   2            772
# 4      618191  2022-01-10         1417                   1            145
#
#    ReceiptRowNumber      Time  ArticleNumber                ArticleName  \
# 0                 1  17:03:58         404805       VL Waldhonig    500g
# 1                 2  17:03:58         435862  VL Eier BY FH H&H 6ST M-L
# 2                 3  17:03:58         425603                     Windel
# 3                 1  18:55:24         425609                     Windel
# 4                 4  19:05:00         432378      Goesser Radler EW0,5L
#
#    Quantity            Timestamp  Month  Day  Hour
# 0       1.0  2022-01-04 17:03:58      1    1    17
# 1       1.0  2022-01-04 17:03:58      1    1    17
# 2       1.0  2022-01-04 17:03:58      1    1    17
# 3       1.0  2022-01-07 18:55:24      1    4    18
# 4       1.0  2022-01-10 19:05:00      1    0    19

# %%
def set_group(x):
    if x['ArticleName'] in ['Pfandartikel (Tandem) - EW', 'Pfandartikel (Tandem) - MW']:
        return "Pfandartikel"
    if x['ArticleName'] in ['BO-Schnittbr.1ST', 'BO-Schnittbroetchen 1ST', 'BO-Kaiserbroetchen 1ST', 'BO-Kaiserbroetchen 65g']:
        return "Broetchen"
    if x['ArticleName'] in ['GL H-Milch1,5%1L VLOG', 'GL H-Milch 3,5% 1L VLOG']:
        return "Milch"
    else:
        return x['ArticleName']

trans['Group'] = trans.apply(set_group, axis=1)

# %%
trans.shape
# Out:
# (9666, 15)

# %%
trans.Group.value_counts()[0:10]
# Out:
# Windel                       850
# Broetchen                     80
# Bananen Lose                  78
# Gurken ST                     71
# Milch                         61
# Schlaufentragetasche ST       54
# Zeitschriften 7%              36
# VL Eier BH 10ST               34
# BO-Laugenbreze 1ST            33
# SZ Fein. Ruebenzucker 1kg     31
# Name: Group, dtype: int64

# %%
# drop articles with overwhelming quantity
trans.drop(trans[trans.Group == "Pfandartikel"].index, inplace=True)
trans.head()
# Out:
#    Unnamed: 0        Date  StoreNumber  CashRegisterNumber  ReceiptNumber  \
# 0      150088  2022-01-04         1303                   2            933
# 1      150089  2022-01-04         1303                   2            933
# 2      150090  2022-01-04         1303                   2            933
# 3      344645  2022-01-07         1053                   2            772
# 4      618191  2022-01-10         1417                   1            145
#
#    ReceiptRowNumber      Time  ArticleNumber                ArticleName  \
# 0                 1  17:03:58         404805       VL Waldhonig    500g
# 1                 2  17:03:58         435862  VL Eier BY FH H&H 6ST M-L
# 2                 3  17:03:58         425603                     Windel
# 3                 1  18:55:24         425609                     Windel
# 4                 4  19:05:00         432378      Goesser Radler EW0,5L
#
#    Quantity            Timestamp  Month  Day  Hour                      Group
# 0       1.0  2022-01-04 17:03:58      1    1    17       VL Waldhonig    500g
# 1       1.0  2022-01-04 17:03:58      1    1    17  VL Eier BY FH H&H 6ST M-L
# 2       1.0  2022-01-04 17:03:58      1    1    17                     Windel
# 3       1.0  2022-01-07 18:55:24      1    4    18                     Windel
# 4       1.0  2022-01-10 19:05:00      1    0    19      Goesser Radler EW0,5L

# %%
# integrate the identical transactions
integrated = trans.groupby(['Date','StoreNumber', 'CashRegisterNumber', 'ReceiptNumber']).agg(Articles=('Group', lambda x:';'.join(x.unique()))).reset_index()
display(integrated.head())

# spilt the integrated transactions into several columns
split_ = integrated['Articles'].str.split(';', expand=True).dropna(how='all', axis=1)
display(split_.head())

for i in range(6):
    mini_article = split_[split_.iloc[:,i].notnull()]
    print(f"The minimum article is {i+1} and the frequency is {mini_article.shape[0]}" )

# filter transactions with at least 4 articles
split_ = split_[split_.iloc[:,2].notnull()]
display(split_.head())

# convert DataFrame to List
# delete the NoneType
res = []
def filter_list(_list):
    for item in _list:
        res.append([x for x in item if x is not None])
filter_list(split_.values.tolist())

transactions_from_df = [tuple(row) for row in res]
transactions_from_df[0:3]

# apriori algorithm
from efficient_apriori import apriori
itemsets, rules = apriori(transactions_from_df, min_support=0.05, min_confidence=0.5)
print("itemsets:",itemsets)
print("rules", rules)
# Out:
#          Date  StoreNumber  CashRegisterNumber  ReceiptNumber  \
# 0  2022-01-04         1303                   2            933
# 1  2022-01-07         1053                   2            772
# 2  2022-01-10         1417                   1            145
# 3  2022-01-14         1303                   1            798
# 4  2022-01-15         1033                   3            421
#
#                                             Articles
# 0  VL Waldhonig    500g;VL Eier BY FH H&H 6ST M-L...
# 1                                             Windel
# 2  Goesser Radler EW0,5L;MonsterUltraWhiteEW0,5L;...
# 3  Windel;GL Naturjogh. 3,5% 500g;SZ Fein. Rueben...
# 4  SB Bio BB R-Hackfl. 400g;Windel;BO-Laugenbreze...
#                          0                          1   \
# 0      VL Waldhonig    500g  VL Eier BY FH H&H 6ST M-L
# 1                    Windel                       None
# 2     Goesser Radler EW0,5L    MonsterUltraWhiteEW0,5L
# 3                    Windel    GL Naturjogh. 3,5% 500g
# 4  SB Bio BB R-Hackfl. 400g                     Windel
#
#                           2                          3   \
# 0                     Windel                       None
# 1                       None                       None
# 2                     Windel  NaturalisMediumEW6x1,5LPK
# 3  SZ Fein. Ruebenzucker 1kg           VL Eier BH 10ST
# 4         BO-Laugenbreze 1ST  MeinQ Fitnessq. sort.180g
#
#                           4                          5   \
# 0                       None                       None
# 1                       None                       None
# 2  M.Mag.A.Nood.o.S.sort.63g  Wa.Stein.Pizza Mozz. 350g
# 3       Banane Chiquita Lose                       None
# 4                  Mangos ST    Nektarinen Gelbfl. Lose
#
#                           6                       7                      8   \
# 0                       None                    None                   None
# 1                       None                    None                   None
# 2  GL Backcamembert oGt 350g  MonsterEnEWsort.0,5LDY  FS Saft Blutorange 1L
# 3                       None                    None                   None
# 4       Apfel Pink Lady Lose         Bio Ingwer Lose           Kiwi Gold ST
#
#                          9   ...    74    75    76    77    78    79    80  \
# 0                      None  ...  None  None  None  None  None  None  None
# 1                      None  ...  None  None  None  None  None  None  None
# 2  SB HM Putenbrust 100g QS  ...  None  None  None  None  None  None  None
# 3                      None  ...  None  None  None  None  None  None  None
# 4   Coca-Cola Zero EW 1,25L  ...  None  None  None  None  None  None  None
#
#      81    82    83
# 0  None  None  None
# 1  None  None  None
# 2  None  None  None
# 3  None  None  None
# 4  None  None  None
#
# [5 rows x 84 columns]
# The minimum article is 1 and the frequency is 847
# The minimum article is 2 and the frequency is 810
# The minimum article is 3 and the frequency is 760
# The minimum article is 4 and the frequency is 683
# The minimum article is 5 and the frequency is 623
# The minimum article is 6 and the frequency is 559
#                          0                          1   \
# 0      VL Waldhonig    500g  VL Eier BY FH H&H 6ST M-L
# 2     Goesser Radler EW0,5L    MonsterUltraWhiteEW0,5L
# 3                    Windel    GL Naturjogh. 3,5% 500g
# 4  SB Bio BB R-Hackfl. 400g                     Windel
# 5    GT Buttersandwich 750g  Diad.ZB Classic hart 2STB
#
#                           2                          3   \
# 0                     Windel                       None
# 2                     Windel  NaturalisMediumEW6x1,5LPK
# 3  SZ Fein. Ruebenzucker 1kg           VL Eier BH 10ST
# 4         BO-Laugenbreze 1ST  MeinQ Fitnessq. sort.180g
# 5       Gewebeband farbig 6m                  Gurken ST
#
#                           4                          5   \
# 0                       None                       None
# 2  M.Mag.A.Nood.o.S.sort.63g  Wa.Stein.Pizza Mozz. 350g
# 3       Banane Chiquita Lose                       None
# 4                  Mangos ST    Nektarinen Gelbfl. Lose
# 5  PrivaMuellbtl.m.Gr.20x50L  PrivaMuellbtl.m.Gr.30x25L
#
#                           6                          7   \
# 0                       None                       None
# 2  GL Backcamembert oGt 350g     MonsterEnEWsort.0,5LDY
# 3                       None                       None
# 4       Apfel Pink Lady Lose            Bio Ingwer Lose
# 5   Salat HaehnchenSenf 300g  HalloWelt Win.3 Midi 46ST
#
#                       8                         9   ...    74    75    76  \
# 0                   None                      None  ...  None  None  None
# 2  FS Saft Blutorange 1L  SB HM Putenbrust 100g QS  ...  None  None  None
# 3                   None                      None  ...  None  None  None
# 4           Kiwi Gold ST   Coca-Cola Zero EW 1,25L  ...  None  None  None
# 5                 Windel                      None  ...  None  None  None
#
#      77    78    79    80    81    82    83
# 0  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None
# 5  None  None  None  None  None  None  None
#
# [5 rows x 84 columns]
# itemsets: {1: {('Windel',): 760, ('Gurken ST',): 71, ('Broetchen',): 75, ('Milch',): 58, ('Bananen Lose',): 78, ('Schlaufentragetasche ST',): 53}, 2: {('Bananen Lose', 'Windel'): 78, ('Broetchen', 'Windel'): 75, ('Gurken ST', 'Windel'): 71, ('Milch', 'Windel'): 58, ('Schlaufentragetasche ST', 'Windel'): 53}}
# rules [{Bananen Lose} -> {Windel}, {Broetchen} -> {Windel}, {Gurken ST} -> {Windel}, {Milch} -> {Windel}, {Schlaufentragetasche ST} -> {Windel}]
